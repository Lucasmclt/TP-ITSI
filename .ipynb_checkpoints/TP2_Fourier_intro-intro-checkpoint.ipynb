# %% [markdown]
# # TP 2 : Introduction au TP Transformée de Fourier
#
#
# ## Objectifs
#
# Le but de ce TP est d'introduire les notions liées à la transformée de Fourier (discrète), et les outils permettant de manipuler et d'analyser cette transformée de Fourier discrète (abrégée TFD par la suite).
#
# Comme n'importe quel signal numérique (stocké sur un support à mémoire finie), les transformées de Fourier que vous aller manipuler dans ce TP (et les suivants) sont <b>discrètes</b>. Dans le cas de la TFD, le passage du monde continu (tel que vu en cours) au monde discret (nécessaire à l'utilisation pratique de cette transformée de Fourier) ne se fait malheureusement pas sans peine. Il va donc être nécessaire de rentrer un peu dans les détails de la représentation numérique d'un signal, malheureusement en amont du cours sur la conversion analogique-numérique.
#
# Au programme de ce TP :
# 1. Le passage du monde continu au monde discret pour la transformée de Fourier.
# 2. Les vraies galères du traitement numérique du signal 😱
#
# Chacune de ces notion est développée dans un *notebook* dédié, pour vous permettre de mieux suivre (et éviter des heures de scroll dans des pages infinies).

# %% [markdown]
# ## Travail à réaliser
#
# Les notebooks que nous vous proposons contiennent des activités de plusieurs types :
# - des notions théoriques à lire et comprendre
# - des démonstrations visuelles pour vous aider à saisir les notions
# - des exercices pour lesquels vous devez programmer une solution à un problème
# - des questions auxquelles vous devez prendre le temps de chercher une réponse
#
# D'une manière générale, il vous suffit de lire chacun des notebooks du début à la fin, en exécutant les cellules au fur et à mesure et en prêtant attention aux résultats affichés.
#
# Certaines cellules doivent être exécutées sans modification (définition des paramètres, des signaux, etc). Ces cellules sont repérées par le symbole 🛑 <br>
# **Lorsque vous aurez à ajouter quelque chose dans un notebook**, comme une réponse à une question ou un bout de code, un message bien clair sera visible :
# ### 🛠️ 🚧 👷  À vous de jouer !
# Dans ce cas, retroussez vos manches et attrapez le clavier !

# %% [markdown]
# # C'est parti !
# Il est à présent temps de passer à la première partie : [le passage du monde continu au monde discret](TP2_Fourier_intro_exo1.ipynb).
